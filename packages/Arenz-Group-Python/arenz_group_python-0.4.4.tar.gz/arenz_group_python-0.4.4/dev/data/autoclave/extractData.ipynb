# %%
from arenz_group_python import AutoClaveSynthesis

# %%
#from arenz_group_python import AutoClaveSynthesis

c = AutoClaveSynthesis("ATS-JF009#01.tdms")
a,b = c.plot("Time_in_min", "T_Reactor_in_C", y_median=5)
a,b = c.plot("Time_in_min", "T_Reactor_in_C", y_median=7)

#a,b = c.plot("Time", "T_Reactor")

# %%
k = c.AC_synthesis(temp_median=5, temp_smooth = 10)
a,b = c.plot("Time_in_min", "T_Reactor_in_C",)

# %%
for a,b in k.items():
    print (a,"\t\t",b)
# Out:
# Set_Temperature 		 200 °C
# Max_Temperature_of_Reactor 		 206.02 °C
# Time_to_Set_Temperature 		 7.84e+01 min
# Heating_Rate 		 2.24 °C/min
# Max_Overpressure 		 27.7 bar
# Time_to_Max_Overpressure 		 104.39 min
# Pressure_Increase_Rate 		 0.25 bar/min
# Rotation_Rate 		 0 rpm
# Duration 		 299.37 min
