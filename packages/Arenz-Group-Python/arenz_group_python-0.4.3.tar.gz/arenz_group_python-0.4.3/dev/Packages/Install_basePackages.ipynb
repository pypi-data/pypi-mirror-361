# %% [markdown]
# # Install Common Packages
# Run this notebook to install most common packages to a python kernal.
#
# Start by placing this file in the root of a project.
# If you are using vscode, create a new venv, before starting.
#
# ### Conda env
# if you are using a conda venv, you might get an error message:
#
# "Running cells with '.conda (Python 3.11.9)' requires the ipykernel package....."
#
# then open the terminal (View menu and then select terminal)
# and then run the code suggested code:.
# Remember to add " " around the path to the venv.
#
# 'conda install -p "\<long Path\>\\.conda" ipykernel --update-deps --force-reinstall'

# %%
import sys
path_to_executable = "\"" + str(sys.executable) +  "\""
print(path_to_executable)
# Out:
# "c:\Users\gusta\AppData\Local\Programs\Python\Python313\python.exe"

# %%
#req_packages = ["pandas","numpy","nptdms","matplotlib","pathlib"]

# %pip install numpy
# %pip install pandas
# %pip install nptdms
# %pip install matplotlib
# %pip install pathlib
# %pip install scipy
# Out:
# Collecting numpyNote: you may need to restart the kernel to use updated packages.
#
#   Downloading numpy-2.1.2-cp313-cp313-win_amd64.whl.metadata (59 kB)
# Downloading numpy-2.1.2-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 2.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/12.6 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.6 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.6 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/12.6 MB 2.6 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.6 MB 2.6 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.6 MB 2.6 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.6 MB 2.7 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.6 MB 2.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.6 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.6 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.6 MB 2.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.6 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 10.0/12.6 MB 2.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.6 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.1.2
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\gusta\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gusta\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gusta\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.6 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.5 MB 3.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.5 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 3.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.5 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 3.8 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Collecting nptdmsNote: you may need to restart the kernel to use updated packages.
#
#   Using cached npTDMS-1.9.0.tar.gz (180 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from nptdms) (2.1.2)
# Building wheels for collected packages: nptdms
#   Building wheel for nptdms (pyproject.toml): started
#   Building wheel for nptdms (pyproject.toml): finished with status 'done'
#   Created wheel for nptdms: filename=npTDMS-1.9.0-py3-none-any.whl size=107844 sha256=82471243d1fbd0b548a4181e3e46427e991d257c6fa760d5ad61dd1673ad06f5
#   Stored in directory: c:\users\gusta\appdata\local\pip\cache\wheels\a3\9a\00\0d128119cc9977cc2b1072ccbe0b496b593109f2faa6c5621f
# Successfully built nptdms
# Installing collected packages: nptdms
# Successfully installed nptdms-1.9.0
#   WARNING: The script tdmsinfo.exe is installed in 'c:\Users\gusta\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading matplotlib-3.9.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp313-cp313-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gusta\appdata\roaming\python\python313\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gusta\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gusta\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp313-cp313-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.8 MB 7.3 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/7.8 MB 7.7 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 8.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp313-cp313-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------------------- - 2.1/2.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 2.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp313-cp313-win_amd64.whl (55 kB)
# Downloading pillow-11.0.0-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------------------------------ --- 2.4/2.6 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 7.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0 pyparsing-3.2.0
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\gusta\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting pathlib
#   Using cached pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Using cached pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting scipy
#   Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.1.2)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#     --------------------------------------- 1.0/44.5 MB 2.7 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/44.5 MB 2.8 MB/s eta 0:00:16
#    -- ------------------------------------- 2.4/44.5 MB 2.9 MB/s eta 0:00:15
#    -- ------------------------------------- 2.9/44.5 MB 2.9 MB/s eta 0:00:15
#    --- ------------------------------------ 3.7/44.5 MB 2.9 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.5/44.5 MB 2.9 MB/s eta 0:00:14
#    ---- ----------------------------------- 5.0/44.5 MB 2.9 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.8/44.5 MB 2.9 MB/s eta 0:00:14
#    ----- ---------------------------------- 6.6/44.5 MB 3.0 MB/s eta 0:00:13
#    ------ --------------------------------- 7.6/44.5 MB 3.0 MB/s eta 0:00:13
#    ------- -------------------------------- 8.4/44.5 MB 3.0 MB/s eta 0:00:12
#    -------- ------------------------------- 9.2/44.5 MB 3.1 MB/s eta 0:00:12
#    -------- ------------------------------- 10.0/44.5 MB 3.1 MB/s eta 0:00:12
#    --------- ------------------------------ 10.7/44.5 MB 3.2 MB/s eta 0:00:11
#    ---------- ----------------------------- 11.5/44.5 MB 3.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 12.3/44.5 MB 3.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 13.1/44.5 MB 3.2 MB/s eta 0:00:10
#    ------------ --------------------------- 14.2/44.5 MB 3.3 MB/s eta 0:00:10
#    ------------- -------------------------- 14.9/44.5 MB 3.3 MB/s eta 0:00:09
#    -------------- ------------------------- 16.0/44.5 MB 3.4 MB/s eta 0:00:09
#    --------------- ------------------------ 16.8/44.5 MB 3.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 17.8/44.5 MB 3.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 18.6/44.5 MB 3.5 MB/s eta 0:00:08
#    ----------------- ---------------------- 19.7/44.5 MB 3.5 MB/s eta 0:00:08
#    ------------------ --------------------- 20.4/44.5 MB 3.5 MB/s eta 0:00:07
#    ------------------- -------------------- 21.5/44.5 MB 3.6 MB/s eta 0:00:07
#    -------------------- ------------------- 22.5/44.5 MB 3.6 MB/s eta 0:00:07
#    --------------------- ------------------ 23.6/44.5 MB 3.6 MB/s eta 0:00:06
#    --------------------- ------------------ 24.4/44.5 MB 3.6 MB/s eta 0:00:06
#    ----------------------- ---------------- 25.7/44.5 MB 3.7 MB/s eta 0:00:06
#    ------------------------ --------------- 26.7/44.5 MB 3.7 MB/s eta 0:00:05
#    ------------------------ --------------- 27.8/44.5 MB 3.8 MB/s eta 0:00:05
#    ------------------------- -------------- 28.8/44.5 MB 3.8 MB/s eta 0:00:05
#    -------------------------- ------------- 29.6/44.5 MB 3.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 31.2/44.5 MB 3.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 32.5/44.5 MB 3.9 MB/s eta 0:00:04
#    ------------------------------ --------- 34.1/44.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 35.4/44.5 MB 3.9 MB/s eta 0:00:03
#    --------------------------------- ------ 36.7/44.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.0/44.5 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/44.5 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------ --- 40.4/44.5 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------- -- 41.7/44.5 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/44.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Check which modules that are installed:

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.43.1
# c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# IPython             binascii            math                stat
# PIL                 bisect              matplotlib          statistics
# __future__          bleach              matplotlib_inline   string
# __hello__           bs4                 mimetypes           stringprep
# __phello__          builtins            mistune             struct
# _abc                bz2                 mmap                subprocess
# _aix_support        cProfile            mmapfile            sunau
# _argon2_cffi_bindings calendar            mmsystem            symtable
# _ast                certifi             modulefinder        sys
# _asyncio            cffi                mpl_toolkits        sysconfig
# _bisect             cgi                 msilib              tabnanny
# _blake2             cgitb               msvcrt              tarfile
# _bz2                charset_normalizer  multiprocessing     telnetlib
# _cffi_backend       chunk               nbclient            tempfile
# _codecs             cmath               nbconvert           terminado
# _codecs_cn          cmd                 nbformat            test
# _codecs_hk          code                nest_asyncio        textwrap
# _codecs_iso2022     codecs              netbios             this
# _codecs_jp          codeop              netrc               threading
# _codecs_kr          collections         nntplib             time
# _codecs_tw          colorama            notebook            timeit
# _collections        colorsys            notebook_shim       timer
# _collections_abc    comm                nptdms              tinycss2
# _compat_pickle      commctrl            nt                  tkinter
# _compression        compileall          ntpath              token
# _contextvars        concurrent          ntsecuritycon       tokenize
# _csv                configparser        nturl2path          tomllib
# _ctypes             contextlib          numbers             tornado
# _ctypes_test        contextvars         numpy               trace
# _datetime           contourpy           odbc                traceback
# _decimal            copy                opcode              tracemalloc
# _elementtree        copyreg             operator            traitlets
# _functools          crypt               optparse            tty
# _hashlib            csv                 os                  turtle
# _heapq              ctypes              overrides           turtledemo
# _imp                curses              packaging           types
# _io                 cycler              pandas              typing
# _json               dataclasses         pandocfilters       tzdata
# _locale             datetime            parso               unicodedata
# _lsprof             dateutil            pathlib             unittest
# _lzma               dbi                 pdb                 uri_template
# _markupbase         dbm                 perfmon             urllib
# _md5                dde                 pickle              urllib3
# _msi                debugpy             pickletools         uu
# _multibytecodec     decimal             pip                 uuid
# _multiprocessing    decorator           pipes               venv
# _opcode             defusedxml          pkgutil             warnings
# _operator           difflib             platform            wave
# _osx_support        dis                 platformdirs        wcwidth
# _overlapped         doctest             plistlib            weakref
# _pickle             email               poplib              webbrowser
# _py_abc             encodings           posixpath           webcolors
# _pydatetime         ensurepip           pprint              webencodings
# _pydecimal          enum                profile             websocket
# _pyio               errno               prometheus_client   win2kras
# _pylong             executing           prompt_toolkit      win32api
# _queue              fastjsonschema      pstats              win32clipboard
# _random             faulthandler        psutil              win32com
# _sha1               filecmp             pty                 win32con
# _sha2               fileinput           pure_eval           win32console
# _sha3               fnmatch             py_compile          win32cred
# _signal             fontTools           py_scripts          win32crypt
# _sitebuiltins       fqdn                pyclbr              win32cryptcon
# _socket             fractions           pycparser           win32event
# _sqlite3            ftplib              pydoc               win32evtlog
# _sre                functools           pydoc_data          win32evtlogutil
# _ssl                gc                  pyexpat             win32file
# _stat               genericpath         pygments            win32gui
# _statistics         getopt              pylab               win32gui_struct
# _string             getpass             pyparsing           win32help
# _strptime           gettext             pythoncom           win32inet
# _struct             glob                pythonjsonlogger    win32inetcon
# _symtable           graphlib            pytz                win32job
# _testbuffer         gzip                pywin               win32lz
# _testcapi           hashlib             pywin32_bootstrap   win32net
# _testclinic         heapq               pywin32_testutil    win32netcon
# _testconsole        hmac                pywintypes          win32pdh
# _testimportmultiple html                queue               win32pdhquery
# _testinternalcapi   http                quopri              win32pdhutil
# _testmultiphase     idlelib             random              win32pipe
# _testsinglephase    idna                rasutil             win32print
# _thread             imaplib             re                  win32process
# _threading_local    imghdr              referencing         win32profile
# _tkinter            importlib           regcheck            win32ras
# _tokenize           inspect             regutil             win32rcparser
# _tracemalloc        io                  reprlib             win32security
# _typing             ipaddress           requests            win32service
# _uuid               ipykernel           rfc3339_validator   win32serviceutil
# _warnings           ipykernel_launcher  rfc3986_validator   win32timezone
# _weakref            isapi               rlcompleter         win32trace
# _weakrefset         isoduration         rpds                win32traceutil
# _win32sysloader     itertools           runpy               win32transaction
# _winapi             jedi                sched               win32ts
# _winxptheme         jinja2              scipy               win32ui
# _wmi                json                secrets             win32uiole
# _xxinterpchannels   json5               select              win32verstamp
# _xxsubinterpreters  jsonpointer         selectors           win32wnet
# _yaml               jsonschema          send2trash          winerror
# _zoneinfo           jsonschema_specifications servicemanager      winioctlcon
# abc                 jupyter             shelve              winnt
# adodbapi            jupyter_client      shlex               winperf
# afxres              jupyter_core        shutil              winpty
# aifc                jupyter_events      signal              winreg
# antigravity         jupyter_lsp         site                winsound
# anyio               jupyter_server      six                 winxpgui
# argon2              jupyter_server_terminals smtplib             winxptheme
# argparse            jupyterlab          sndhdr              wsgiref
# array               jupyterlab_pygments sniffio             xdrlib
# arrow               jupyterlab_server   socket              xml
# ast                 keyword             socketserver        xmlrpc
# asttokens           kiwisolver          soupsieve           xxsubtype
# async_lru           lib2to3             sqlite3             yaml
# asyncio             linecache           sre_compile         zipapp
# atexit              locale              sre_constants       zipfile
# attr                logging             sre_parse           zipimport
# attrs               lzma                ssl                 zlib
# audioop             mailbox             sspi                zmq
# babel               mailcap             sspicon             zoneinfo
# base64              markupsafe          stack_data
# bdb                 marshal             start_pythonwin
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# !{path_to_executable} -m pip install pooch
# Out:
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\gusta\documents\github\arenz_group_python\.venv\lib\site-packages (from pooch) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gusta\documents\github\arenz_group_python\.venv\lib\site-packages (from pooch) (24.1)
# Collecting requests>=2.19.0 (from pooch)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ---------------------------------------- 163.0/163.0 kB 3.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 1.9 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.4 kB ? eta -:--:--
#    ---------------------------------------- 121.4/121.4 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, pooch
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 pooch-1.8.2 requests-2.32.3 urllib3-2.2.2
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
